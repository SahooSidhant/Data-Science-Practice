# %% [markdown]
# # Lesson 1.2: Python Basics
# ## Topics Covered:
# - Syntax and Semantics
# - Variables and Data Types
# - Basic Operators (Arithmetic, Comparison, Logical)

# %% [markdown]
# ## 1. Syntax and Semantics
#
# **Question 1:** Write a Python program to print "Hello, World!".

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %% [markdown]
# **Question 2:** Write a Python program that takes a user input and prints it.

# %%
Uinp = input("Enter your Name: ")
print(f'{Uinp}')
# Out:
# Sidhant

# %% [markdown]
# **Question 3:** Write a Python program to check if a number is positive, negative, or zero.

# %%
n = int(input("Enter a Number: "))
if n == 0:
    print(f'{n} is Zero')
elif n > 0:
    print(f'{n} is Positive')
else:
    print(f'{n} is Negative')
# Out:
# -3 is Negative

# %% [markdown]
# **Question 4:** Write a Python program to find the largest of three numbers.

# %%
n1 = int(input("Enter First Number: "))
n2 = int(input("Enter Second Number: "))
n3 = int(input("Enter Third Number: "))
print(f'Largest Number is: {max(n1, n2, n3)}')
# Out:
# Largest Number is: 6

# %% [markdown]
# **Question 5:** Write a Python program to calculate the factorial of a number.

# %%
def fact(n):
    if n == 0 or n == 1:
        return 1
    else:
        return n * fact(n-1)
    
num = int(input("Enter a Number: "))
print(f'Fatorial of {num} is: {fact(num)}')
# Out:
# Fatorial of 22 is: 1124000727777607680000

# %% [markdown]
# ## 2. Variables and Data Types
#
# **Question 6:** Create variables of different data types: integer, float, string, and boolean. Print their values and types.

# %%
n1 = int(input("Enter First Number: "))
n2 = float(n1)
n3 = bool(0)
n4 = str(n1)

print(f'Integer: {type(n1)}', f'Float: {type(n2)}', f'Boolean: {n3}', f'String: {type(n4)}', sep='\n')
# Out:
# Integer: <class 'int'>
# Float: <class 'float'>
# Boolean: False
# String: <class 'str'>

# %% [markdown]
# **Question 7:** Write a Python program to swap the values of two variables.

# %%
a = 10
b = 20
print(f'Before Swapping: a = {a}, b = {b}')
a, b = b, a
print(f'After Swapping: a = {a}, b = {b}')
# Out:
# Before Swapping: a = 10, b = 20
# After Swapping: a = 20, b = 10

# %% [markdown]
# **Question 8:** Write a Python program to convert Celsius to Fahrenheit.

# %%
c = int(input("Entr the Temperature in Celsius: "))
f = (c*9/5)+32
print(f'{c}°C is equal to {f}°F')
# Out:
# 57°C is equal to 134.6°F

# %% [markdown]
# **Question 9:** Write a Python program to concatenate two strings.

# %%
s1 = input("Enter First String: ")
s2 = input("Enter Second String: ")
print(f'Concatenated String: {s1 +" "+ s2}')
# Out:
# Concatenated String: Sidhant Sahoo

# %% [markdown]
# **Question 10:** Write a Python program to check if a variable is of a specific data type.

# %%
n = 10.0

if isinstance(n, float):
    print(f'{n} is a Float')
else:
    print(f'{n} is not a Float')
# Out:
# 10.0 is a Float

# %% [markdown]
# ## 3. Basic Operators (Arithmetic, Comparison, Logical)
#
# **Question 11:** Write a Python program to perform arithmetic operations: addition, subtraction, multiplication, and division.

# %%
a = 5
b = 3

print(f"Addition: {a} + {b} = {a + b}")
print(f"Subtraction: {a} - {b} = {a - b}")
print(f"Multiplication: {a} * {b} = {a * b}")
print(f"Division: {a} / {b} = {a / b}")
# Out:
# Addition: 5 + 3 = 8
# Subtraction: 5 - 3 = 2
# Multiplication: 5 * 3 = 15
# Division: 5 / 3 = 1.6666666666666667

# %% [markdown]
# **Question 12:** Write a Python program to demonstrate comparison operators: equal to, not equal to, greater than, less than.

# %%
a = 5
b = 3

print(f"{a} == {b}: {a == b}")
print(f"{a} != {b}: {a != b}")
print(f"{a} > {b}: {a > b}")
print(f"{a} < {b}: {a < b}")
# Out:
# 5 == 3: False
# 5 != 3: True
# 5 > 3: True
# 5 < 3: False

# %% [markdown]
# **Question 13:** Write a Python program to demonstrate logical operators: and, or, not.

# %%
a = True
b = False
print(f'Logical AND: {a and b}', f'Logical OR: {a or b}', f'Logical NOT a: {not a}', f'Logical NOT b: {not b}', sep='\n')
# Out:
# Logical AND: False
# Logical OR: True
# Logical NOT a: False
# Logical NOT b: True

# %% [markdown]
# **Question 14:** Write a Python program to calculate the square of a number.

# %%
num = float(input("Enter a number: "))
square = num ** 2
print(f"The square of {num} is {square}")
# Out:
# The square of 44.0 is 1936.0

# %% [markdown]
# **Question 15:** Write a Python program to check if a number is even or odd.

# %%
num = int(input("Enter a number: "))
if num % 2 == 0:
    print(f"{num} is even.")
else:
    print(f"{num} is odd.")
# Out:
# 4 is even.

# %% [markdown]
# **Question 16:** Write a Python program to find the sum of the first n natural numbers.

# %%
# Your code here

# %% [markdown]
# **Question 17:** Write a Python program to check if a year is a leap year.

# %%
year = int(input("Enter a year: "))
if (year % 4 ==0 and year % 100 != 0) or (year % 400 == 0):
    print(f'{year} is a Leap Year')
# Out:
# 2024 is a Leap Year

# %% [markdown]
# **Question 18:** Write a Python program to reverse a string.

# %%
s = input("Enter a String: ")
rev_s = s[::-1]
print(f'Reversed String: {rev_s}')
# Out:
# Reversed String: DIIIIIS

# %% [markdown]
# **Question 19:** Write a Python program to check if a string is a palindrome.

# %%
s = input("Enter a String: ")
if s == s[::-1]:
    print("The string is a palindrome.")
else:
    print("The string is not a palindrome.")
# Out:
# The string is a palindrome.

# %% [markdown]
# **Question 20:** Write a Python program to sort a list of numbers in ascending order.

# %%
numbers = [int(x) for x in input("Enter numbers separated by space: ").split()]
numbers.sort()
print(f"Sorted list: {numbers}")
# Out:
# Sorted list: [3, 6, 7]
